# %%
import pandas as pd
data = pd.read_csv('treino_sinais_vitais_com_label.txt', header=None)
data
# Out:
#          0          1          2         3           4          5          6  \
# 0        1  13.592433  12.220855  8.416754   75.921057  21.635259  40.000000
# 1        2  15.775386  13.586879  8.725890   63.813564  19.718734  41.530427
# 2        3   3.649369   1.904802  0.000000  197.210213  19.045471  52.730745
# 3        4  17.264362  13.700638  8.733333  143.636181  17.621141  34.679911
# 4        5  12.705183   9.485389  1.747626   82.636672  12.209535  69.375882
# ...    ...        ...        ...       ...         ...        ...        ...
# 1495  1496  17.151411   6.020803  4.774128    6.701052   7.380529  24.494467
# 1496  1497  13.114511  12.500453  8.400144   81.203081  13.630509  65.385011
# 1497  1498  17.976320   6.054430  4.768427  143.261527  21.843486  24.530704
# 1498  1499  12.640997   5.852639  1.707746  184.267283  14.256125  61.062546
# 1499  1500  18.869140   5.406733  4.745181  196.803149  11.875068  39.110506
#
#       7
# 0     2
# 1     2
# 2     3
# ...

# %%
#data = data.drop([0,1,2,6], axis=1)

# %%
data = data.rename(columns={
    7:"classe"
})
data
# Out:
#              3           4          5  classe
# 0     8.416754   75.921057  21.635259       2
# 1     8.725890   63.813564  19.718734       2
# 2     0.000000  197.210213  19.045471       3
# 3     8.733333  143.636181  17.621141       2
# 4     1.747626   82.636672  12.209535       3
# ...        ...         ...        ...     ...
# 1495  4.774128    6.701052   7.380529       1
# 1496  8.400144   81.203081  13.630509       3
# 1497  4.768427  143.261527  21.843486       1
# 1498  1.707746  184.267283  14.256125       3
# 1499  4.745181  196.803149  11.875068       2
#
# [1500 rows x 4 columns]

# %%
datax = data[[3,4,5]]
datay = data[["classe"]]

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(datax, datay, test_size=0.2)

# %%
#import numpy as np
ytest = np.array(y_test['classe'].values)

# %%
from sklearn.neural_network import MLPClassifier
# lbfgs, reLU

adam = MLPClassifier(solver='adam',hidden_layer_sizes=(100),max_iter= 200000)
adam.fit(X_train,y_train)
sgd = MLPClassifier(solver='sgd',hidden_layer_sizes=(100),max_iter= 200000)
sgd.fit(X_train,y_train)
lbfgs = MLPClassifier(solver='lbfgs',hidden_layer_sizes=(100),max_iter= 200000)
lbfgs.fit(X_train,y_train)
# Out:
# C:\Users\luish\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1096: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\luish\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1096: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\luish\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1096: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MLPClassifier(hidden_layer_sizes=100, max_iter=200000, solver='lbfgs')

# %%
adam_predictions = adam.predict(X_test)
sgd_predictions = sgd.predict(X_test)
lbfgs_predictions = lbfgs.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
adam_acuracia = accuracy_score(ytest, adam_predictions)
sgd_acuracia = accuracy_score(ytest, sgd_predictions)
lbfgs_acuracia = accuracy_score(ytest, lbfgs_predictions)

# %%
print('Adam : ',adam_acuracia)
print('SGD : ',sgd_acuracia)
print('LBFGS : ',lbfgs_acuracia)
# Out:
# Adam :  0.6566666666666666
# SGD :  0.6966666666666667
# LBFGS :  0.7766666666666666
